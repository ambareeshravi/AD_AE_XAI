# %%
from utils import *
from model_utils import *
from data import *
from c2d_models import *
from test_pipeline import *
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /home/ambreesh/Documents/amb_venv/src/deepexplain/deepexplain/tensorflow/methods.py:559: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.

# %%
train_data = MVTec(isTrain = True)
# Out:
# 100%|██████████| 17/17 [01:48<00:00,  6.36s/it]

# %%
config = {
    'lime': {
        'num_features': 128*128,
        'mask_features': 5,
        'num_samples': 1000,
    },
    'counterfactual': {
        'threshold_pct': 0.98,
        'block_size': 32
    },
    'shap': {
        'blend_alpha': 0.85,
        'background_samples': 100
    },
    'elrp': {
        'max_loss_value': 1000
    },
    'output_path': "results/MVTec/",
    'test_data_path': "TEST_SETS/MVTec/",
    'train_data': train_data.data, # np.array of normal images
    'max_loss_value': 1000,
    'batch_size': 64,
    'data_name': "MVTec",
    'model_path': "trained_models/C2D_AE_128_3x3_MVTec/model.h5"
}

# %%
model_path = "trained_models/C2D_AE_128_3x3_HAM10000/model.h5"
rec_model = get_model(model_path)
loss_model = get_model(model_path, rec=False)
# Out:
# WARNING:tensorflow:From /home/ambreesh/Documents/amb_venv/lib/python3.6/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.

# %%
output_path = config["output_path"]
test_path = config['test_data_path']
for category_dir in read_directory_contents(test_path):
    category_type = os.path.split(category_dir)[-1]
    INFO(category_type)
    config["output_path"] = join_paths([output_path, category_type, ""])
    config['data_name'] = category_type
    create_directory(config["output_path"])
    config['test_data_path'] = category_dir
    
    _pipline = Pipeline(rec_model, loss_model, config)
    _pipline.run()
# Out:
# ----------------------------------------
# bottle
# ----------------------------------------
# WARNING:tensorflow:From /home/ambreesh/Documents/amb_venv/lib/python3.6/site-packages/shap/explainers/tf_utils.py:28: The name tf.keras.backend.get_session is deprecated. Please use tf.compat.v1.keras.backend.get_session instead.
# keras is no longer supported, please use tf.keras instead.
# ----------------------------------------
# e-LRP ready
# ----------------------------------------
# Saving to results/MVTec/bottle/e-LRP/
# WARNING:tensorflow:From /home/ambreesh/Documents/amb_venv/src/deepexplain/deepexplain/tensorflow/methods.py:638: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
# WARNING:tensorflow:From /home/ambreesh/Documents/amb_venv/src/deepexplain/deepexplain/tensorflow/methods.py:638: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
# ...

# %%
p = Pipeline(rec_model, loss_model, confg)

# %%
p.run()

# %%
exit()

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !pip install lime

# %%
import os
os.chdir('/content/drive/My Drive/explainable-ad/code')

# %%
from utils import *
from model_utils import *
from data import *
from c2d_models import *
from test_pipeline import *

# %%
import os
import shutil

root = "trash/mv-tec-test-samples/"
output_root = "trash/output/"
directories = [ item for item in os.listdir(root) if os.path.isdir(os.path.join(root, item)) ]
for dir in directories:
    output_dir = os.path.join(output_root, dir)
    create_directory(output_dir)
    test_dir = os.path.join(root, dir) + "/test"
    for case in os.listdir(test_dir):
        case_dir = os.path.join(test_dir, case)
        output_case_dir = os.path.join(output_dir, case)
        create_directory(output_case_dir)
        
        total_samples = []
        for f in os.listdir(case_dir):
            total_samples.append(os.path.join(case_dir,f))

        idx = np.random.randint(0, len(total_samples), 30)
        total_samples = np.array(total_samples)
        batch_samples = total_samples[idx]

        for img in batch_samples:
            shutil.copy(img, output_case_dir)

# %%
import os
import shutil

output_root = "/content/drive/My Drive/explainable-ad/mvtec-test-samples"
for dir in os.listdir(output_root):
    for case in os.listdir(os.path.join(output_root, dir)):
        if case == 'good':
            case_dir = os.path.join(output_root, dir) + '/' + case
            new_dir = os.path.join(output_root, dir) + '/normal'
            os.rename(case_dir, new_dir)

# %%
import os
import shutil

root = "/content/drive/My Drive/explainable-ad/HAM10000_SPLIT/ABNORMAL/"
output_root = "/content/drive/My Drive/explainable-ad/ham10000-test-samples"
directories = [ item for item in os.listdir(root) if os.path.isdir(os.path.join(root, item)) ]
for dir in directories:
    output_dir = os.path.join(output_root, dir)
    create_directory(output_dir)
    test_dir = os.path.join(root, dir) + "/test"
    for case in os.listdir(test_dir):
        case_dir = os.path.join(test_dir, case)
        output_case_dir = os.path.join(output_dir, case)
        create_directory(output_case_dir)
        
        total_samples = []
        for f in os.listdir(case_dir):
            total_samples.append(os.path.join(case_dir,f))

        idx = np.random.randint(0, len(total_samples), 30)
        total_samples = np.array(total_samples)
        batch_samples = total_samples[idx]

        for img in batch_samples:
            shutil.copy(img, output_case_dir)

# %%
import os
import shutil
import numpy as np

root = "/content/drive/My Drive/explainable-ad/HAM10000_SPLIT/ABNORMAL/DF/df/"
output_root = "/content/drive/My Drive/explainable-ad/ham10000-test-samples/df/"

total_samples = []
for item in os.listdir(root):
    total_samples.append(os.path.join(root, item))

idx = np.random.randint(0, len(total_samples), 30)
total_samples = np.array(total_samples)
batch_samples = total_samples[idx]

for img in batch_samples:
    shutil.copy(img, output_root)

# %%
from tensorflow import keras
C2D_MODEL_PATH = "/content/drive/My Drive/explainable-ad/lr-model.h5"

def get_model(rec = True, max_value=1000):
    if rec: model = C2D_AE_128_3x3(isTrain = True)
    else: model = C2D_AE_128_3x3(isTrain = False, max_value = max_value)
    model.model.load_weights(C2D_MODEL_PATH)
    return model.model

lr_model = get_model(True)
lr_loss_model = get_model(False)

# %%
model_path = "trained_models/C2D_AE_128_3x3_MVTec/model.h5"
lr_model = get_model(model_path)
lr_loss_model = get_model(model_path, rec=False)

# %%
config = {
    'lime': {
        'batch_size': 32,
        'num_features': 128*128,
        'mask_features': 5,
        'num_samples': 1000,
    },
    'counterfactual': {
        'threshold_pct': 0.98,
        'block_size': 32
    },
    'output_path': "trash/output/",
    'test_data_path': "trash/mv-tec-test-samples/pill/",
    'training_data_path': "../datasets/VAD_Datasets/MV_TEC/"
}

# %%
pipline = Pipeline(lr_model, lr_loss_model, config)

# %%
pipline.run()

# %%
from tensorflow import keras
C2D_MODEL_PATH = "/content/drive/My Drive/explainable-ad/C2D_AE_128_3x3_HAM10000/model.h5"

def get_model(rec = True, max_value=1000):
    if rec: model = C2D_AE_128_3x3(isTrain = True)
    else: model = C2D_AE_128_3x3(isTrain = False, max_value = max_value)
    model.model.load_weights(C2D_MODEL_PATH)
    return model.model

ham_model = get_model(True)
ham_loss_model = get_model(False)

# %%
from tensorflow import keras
C2D_MODEL_PATH = "/content/drive/My Drive/explainable-ad/mvc-model.h5"

def get_model(rec = True, max_value=1000):
    if rec: model = C2D_AE_128_3x3(isTrain = True)
    else: model = C2D_AE_128_3x3(isTrain = False, max_value = max_value)
    model.model.load_weights(C2D_MODEL_PATH)
    return model.model

mvc_model = get_model(True)
mvc_loss_model = get_model(False)

# %%
root_test_dir = "/content/drive/My Drive/explainable-ad/ham10000-test-samples"
root_output_path = "/content/drive/My Drive/explainable-ad/ham10000-output"

config = {
    'lime': {
        'batch_size': 32,
        'num_features': 128*128,
        'mask_features': 5
    },
    'counterfactual': {
        'threshold_pct': 0.98,
        'block_size': 16
    },
    'output_path': "/content/drive/My Drive/explainable-ad/ham10000-output",
    'test_data_path': "/content/drive/My Drive/explainable-ad/ham10000-test-samples",
}
config['test_data_path'] = root_test_dir
config['output_path'] = root_output_path + '/'

pipline = Pipeline(ham_model, ham_loss_model, config)
pipline.run()

# %%
root_test_dir = "trash/mv-tec-test-samples/pill/"
root_output_path = "trash/output/"

for dir in os.listdir(root_test_dir):
    type_dir = os.path.join(root_test_dir, dir)
    output_type_dir = os.path.join(root_output_path, dir)
    print(output_type_dir)
    print(read_directory_contents(type_dir))
    create_directory(type_dir)
    config = {
        'lime': {
            'batch_size': 64,
            'num_features': 128*128,
            'mask_features': 5,
            'num_samples': 1000
        },
        'counterfactual': {
            'threshold_pct': 0.98,
            'block_size': 16
        },
        'output_path': "trash/",
        'test_data_path': "../datasets/VAD_Datasets/MV_TEC/",
    }
    config['test_data_path'] = type_dir
    config['output_path'] = output_type_dir + '/'

    _pipline = Pipeline(lr_model, lr_loss_model, config)
    _pipline.run()

# %%
DATASET = "HAM10000"
TEST_DIR = join_paths(["TEST_SETS/", DATASET, ""])

test_dict = dict()
for class_dir in read_directory_contents(TEST_DIR):
    test_dict[class_dir.split("/")[-1]] = np.array([read_image(file, resize_to=(128,128))/255. for file in read_directory_contents(class_dir)])
    
# 1 -> High Loss -> Anomaly
# 0 -> Low Loss -> Normal
X_test = list()
y_test = list()
for key in set(test_dict.keys()):
    X_test.append(test_dict[key])
    y_test += [0 if "normal" in key else 1]*len(test_dict[key])
X_test = np.concatenate(X_test)
y_test = np.array(y_test)

# %%
TEST_DIR = '/content/drive/My Drive/explainable-ad/ham10000-test-samples'

test_dict = dict()
for class_dir in read_directory_contents(TEST_DIR):
    test_dict[class_dir.split("/")[-1]] = np.array([read_image(file, resize_to=(128,128))/255. for file in read_directory_contents(class_dir)])

# %%
X_test = list()
y_test = list()
for key in set(test_dict.keys()):
    X_test.append(test_dict[key])
    y_test += [0 if "normal" in key else 1]*len(test_dict[key])
X_test = np.concatenate(X_test)
y_test = np.array(y_test)

# %%
X_test.shape

# %%
test_lime = LimeExplainer(ham_loss_model, 128*128, 1000, 64)

# %%
idx = np.random.randint(0, len(total_samples), 10)

X_test_new = X_test[idx]

# %%
lime_results = test_lime.explain(X_test_new, results_path="", mask_features=5, anomaly_type=None, save_result=False)

# %%
test_dict = dict()
for class_dir in read_directory_contents('/content/drive/My Drive/explainable-ad/mvtec-test-samples/cable'):
    test_dict[class_dir.split("/")[-1]] = np.array([read_image(file, resize_to=(128,128))/255. for file in read_directory_contents(class_dir)])

# %%
test_dict.keys()

# %%
test_lime = LimeExplainer(mvc_loss_model, 128*128, 1000, 64)

# %%
test_dict['bent_wire'].shape

# %%
lime_results = test_lime.explain(test_dict['bent_wire'], results_path="/content/drive/My Drive/explainable-ad/mvtec-output/cable/lime", mask_features=5, anomaly_type=None, save_result=True)
